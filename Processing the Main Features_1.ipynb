# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("cleaning.csv")

# %%
df
# Out:
#             location   date_of_sale number_of_bedrooms     price  \
# 0            Clapham     12/04/1999                  1  £729,000
# 1            Ashford     05/08/2017            unknown  £699,000
# 2  Stratford-on-Avon     29/03/2012                  3       NaN
# 3         Canterbury     01/07/2009                  2  £529,000
# 4             Camden     16/12/2001                  1  £616,000
# 5              Rugby     01/03/2003                  -  £247,000
# 6          Hampstead     05/03/2016                  2        £0
# 7            Clapham     05/07/2001                363  £543,000
# 8  Stratford-on-Avon  10th May 2010                  3  £420,000
# 9             Camden     16/12/2001                  1  £616,000
#
#             type
# 0      apartment
# 1  semi-detached
# 2       detached
# 3        teraced
# 4      apartment
# 5       detached
# 6       terraced
# 7      apartment
# 8       detached
# 9      apartment

# %%
##examin our data
df.dtypes
# Out:
# location              object
# date_of_sale          object
# number_of_bedrooms    object
# price                 object
# type                  object
# dtype: object

# %%
df.isnull().mean()
# Out:
# location              0.0
# date_of_sale          0.0
# number_of_bedrooms    0.0
# price                 0.1
# type                  0.0
# dtype: float64

# %%
df["date_of_sale"]=pd.to_datetime(df["date_of_sale"])

# %%
df.dtypes
# Out:
# location                      object
# date_of_sale          datetime64[ns]
# number_of_bedrooms            object
# price                         object
# type                          object
# dtype: object

# %%
non_nums= df[~df["number_of_bedrooms"].str.isnumeric()]["number_of_bedrooms"].unique()

# %%
df["number_of_bedrooms"].replace(non_nums, np.nan)
df["number_of_bedrooms"]
# Out:
# 0          1
# 1    unknown
# 2          3
# 3          2
# 4          1
# 5          -
# 6          2
# 7        363
# 8          3
# 9          1
# Name: number_of_bedrooms, dtype: object

# %%
##df['number_of_bedrooms'] = pd.to_numeric(df['number_of_bedrooms'])
##df["number_of_bedroom"]= df["number_of_bedroom"].apply(lambda x: x. replace(',', '')if type(x) is str else x)

# %%
df.dtypes
# Out:
# location                      object
# date_of_sale          datetime64[ns]
# number_of_bedrooms            object
# price                         object
# type                          object
# dtype: object

# %%
df.price
# Out:
# 0    £729,000
# 1    £699,000
# 2         NaN
# 3    £529,000
# 4    £616,000
# 5    £247,000
# 6          £0
# 7    £543,000
# 8    £420,000
# 9    £616,000
# Name: price, dtype: object

# %%
df["price"]= df["price"].apply(lambda x: x. replace(',', '')if type(x) is str else x)

# %%
df
# Out:
#             location date_of_sale number_of_bedrooms    price           type
# 0            Clapham   1999-12-04                  1  £729000      apartment
# 1            Ashford   2017-05-08            unknown  £699000  semi-detached
# 2  Stratford-on-Avon   2012-03-29                  3      NaN       detached
# 3         Canterbury   2009-01-07                  2  £529000        teraced
# 4             Camden   2001-12-16                  1  £616000      apartment
# 5              Rugby   2003-01-03                  -  £247000       detached
# 6          Hampstead   2016-05-03                  2       £0       terraced
# 7            Clapham   2001-05-07                363  £543000      apartment
# 8  Stratford-on-Avon   2010-05-10                  3  £420000       detached
# 9             Camden   2001-12-16                  1  £616000      apartment

# %%
df["price"]= df["price"].apply(lambda x: x. replace('£', '')if type(x) is str else x)

# %%
df
# Out:
#             location date_of_sale number_of_bedrooms   price           type
# 0            Clapham   1999-12-04                  1  729000      apartment
# 1            Ashford   2017-05-08            unknown  699000  semi-detached
# 2  Stratford-on-Avon   2012-03-29                  3     NaN       detached
# 3         Canterbury   2009-01-07                  2  529000        teraced
# 4             Camden   2001-12-16                  1  616000      apartment
# 5              Rugby   2003-01-03                  -  247000       detached
# 6          Hampstead   2016-05-03                  2       0       terraced
# 7            Clapham   2001-05-07                363  543000      apartment
# 8  Stratford-on-Avon   2010-05-10                  3  420000       detached
# 9             Camden   2001-12-16                  1  616000      apartment

# %%
df["price"]= pd.to_numeric(df["price"])

# %%
df
# Out:
#             location date_of_sale number_of_bedrooms     price           type
# 0            Clapham   1999-12-04                  1  729000.0      apartment
# 1            Ashford   2017-05-08            unknown  699000.0  semi-detached
# 2  Stratford-on-Avon   2012-03-29                  3       NaN       detached
# 3         Canterbury   2009-01-07                  2  529000.0        teraced
# 4             Camden   2001-12-16                  1  616000.0      apartment
# 5              Rugby   2003-01-03                  -  247000.0       detached
# 6          Hampstead   2016-05-03                  2       0.0       terraced
# 7            Clapham   2001-05-07                363  543000.0      apartment
# 8  Stratford-on-Avon   2010-05-10                  3  420000.0       detached
# 9             Camden   2001-12-16                  1  616000.0      apartment

# %%
df["price"]= df["price"].replace([0], np.nan)

# %%
df
# Out:
#             location date_of_sale number_of_bedrooms     price           type
# 0            Clapham   1999-12-04                  1  729000.0      apartment
# 1            Ashford   2017-05-08            unknown  699000.0  semi-detached
# 2  Stratford-on-Avon   2012-03-29                  3       NaN       detached
# 3         Canterbury   2009-01-07                  2  529000.0        teraced
# 4             Camden   2001-12-16                  1  616000.0      apartment
# 5              Rugby   2003-01-03                  -  247000.0       detached
# 6          Hampstead   2016-05-03                  2       NaN       terraced
# 7            Clapham   2001-05-07                363  543000.0      apartment
# 8  Stratford-on-Avon   2010-05-10                  3  420000.0       detached
# 9             Camden   2001-12-16                  1  616000.0      apartment

# %%
df["type"].unique()
# Out:
# array(['apartment', 'semi-detached', 'detached', 'teraced', 'terraced'],
#       dtype=object)

# %%
df["type"]= df["type"].replace(['teraced'],'terraced')

# %%
df["type"].unique()
# Out:
# array(['apartment', 'semi-detached', 'detached', 'terraced'], dtype=object)

# %%
##part2 Processing outliers and duplicates

# %%
df
# Out:
#             location date_of_sale number_of_bedrooms     price           type
# 0            Clapham   1999-12-04                  1  729000.0      apartment
# 1            Ashford   2017-05-08            unknown  699000.0  semi-detached
# 2  Stratford-on-Avon   2012-03-29                  3       NaN       detached
# 3         Canterbury   2009-01-07                  2  529000.0       terraced
# 4             Camden   2001-12-16                  1  616000.0      apartment
# 5              Rugby   2003-01-03                  -  247000.0       detached
# 6          Hampstead   2016-05-03                  2       NaN       terraced
# 7            Clapham   2001-05-07                363  543000.0      apartment
# 8  Stratford-on-Avon   2010-05-10                  3  420000.0       detached
# 9             Camden   2001-12-16                  1  616000.0      apartment

# %%
##find_outliers(df.number_of_bedrooms)

# %%
##find_outliers(df.price)

# %%
#boxPlotAll(df["number_of_bedroom","price"])

# %%
#df.loc[7,'number_of_bedrooms']= np.NaN

# %%
df=df.drop(7)

# %%
df
# Out:
#             location date_of_sale number_of_bedrooms     price           type
# 0            Clapham   1999-12-04                  1  729000.0      apartment
# 1            Ashford   2017-05-08            unknown  699000.0  semi-detached
# 2  Stratford-on-Avon   2012-03-29                  3       NaN       detached
# 3         Canterbury   2009-01-07                  2  529000.0       terraced
# 4             Camden   2001-12-16                  1  616000.0      apartment
# 5              Rugby   2003-01-03                  -  247000.0       detached
# 6          Hampstead   2016-05-03                  2       NaN       terraced
# 8  Stratford-on-Avon   2010-05-10                  3  420000.0       detached
# 9             Camden   2001-12-16                  1  616000.0      apartment

# %%
##Duplicates

# %%
df[df.duplicated()]
# Out:
#   location date_of_sale number_of_bedrooms     price       type
# 9   Camden   2001-12-16                  1  616000.0  apartment

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#             location date_of_sale number_of_bedrooms     price           type
# 0            Clapham   1999-12-04                  1  729000.0      apartment
# 1            Ashford   2017-05-08            unknown  699000.0  semi-detached
# 2  Stratford-on-Avon   2012-03-29                  3       NaN       detached
# 3         Canterbury   2009-01-07                  2  529000.0       terraced
# 4             Camden   2001-12-16                  1  616000.0      apartment
# 5              Rugby   2003-01-03                  -  247000.0       detached
# 6          Hampstead   2016-05-03                  2       NaN       terraced
# 8  Stratford-on-Avon   2010-05-10                  3  420000.0       detached
